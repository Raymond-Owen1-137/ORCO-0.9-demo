# %% [markdown]
# # ORCO 0.9 Demo
# This notebook runs the ORCO residue assignment demo from a clean environment.

# %%
# !pip install pandas numpy

# %%
# Upload required files
from google.colab import files
uploaded = files.upload()

# %%
# Run the ORCO pipeline
# !python3 main.py
